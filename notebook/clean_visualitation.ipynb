# %%
import pandas as pd

import re
import folium

import warnings
warnings.filterwarnings('ignore')

import pylab as plt
import seaborn as sns

# %%
lineas = pd.read_excel('../data/toplogia.xlsx')

# %%
lineas.head()
# Out:
#    Route code gmv Route           Route Name  Line code         Line Name  \
# 0               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
# 1               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
# 2               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
# 3               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
# 4               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
#
#    Stop Order  Stop Code GMV    Stop Name  Stop Code Alsa   Latitude  \
# 0           1          10005  Bab Chellah           73006  34.023298
# 1           2          10007   Bab Mellah           73008  34.025001
# 2           3          10044   Bab Khmiss           73046  34.036633
# 3           4          10046         Diar           73048  34.041434
# 4           5          10048     Mkinsiya           73050  34.044136
#
#    Longitude
# 0  -6.834576
# 1  -6.829615
# 2  -6.817232
# 3  -6.816444
# 4  -6.817705

# %%
# Modifico nombres de columnas a minúsculas y separadas por _

lineas.columns=[c.lower().replace(' ', '_') for c in lineas.columns]

# %%
# Modifico latitud y longitud para que venga separado por un punto

lineas[['latitude', 'longitude']] = lineas[['latitude', 'longitude']].apply(lambda x: x.replace(',', '.'))

# %%
lineas.head()
# Out:
#    route_code_gmv route           route_name  line_code         line_name  \
# 0               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
# 1               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
# 2               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
# 3               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
# 4               1    L1  L1 BAB CHELLAH-DOHA        103  BAB CHALLEH-DOHA
#
#    stop_order  stop_code_gmv    stop_name  stop_code_alsa   latitude  \
# 0           1          10005  Bab Chellah           73006  34.023298
# 1           2          10007   Bab Mellah           73008  34.025001
# 2           3          10044   Bab Khmiss           73046  34.036633
# 3           4          10046         Diar           73048  34.041434
# 4           5          10048     Mkinsiya           73050  34.044136
#
#    longitude
# 0  -6.834576
# 1  -6.829615
# 2  -6.817232
# 3  -6.816444
# 4  -6.817705

# %%
def geomap(df, zoom_start=1.5):

    df.index=range(len(df)) 

    mapa=folium.Map(location=[0, 0],
                tiles='openstreetmap', zoom_start=zoom_start)

    for i in range(1, len(df)):

        folium.CircleMarker([float(df.latitude[i]), float(df.longitude[i])], 
                             radius=1, icon=folium.Icon()).add_to(mapa)

    mapa.save('../images/geomap.html')
    
    
    return mapa

# %%
print('Lineas')

mapa=geomap(lineas.loc[:1500])
mapa
# Out:
# Lineas
# ...
